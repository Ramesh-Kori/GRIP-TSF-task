# %% [markdown]
# # **GRIP @ THE SPARKS FOUNDATION**
#
# Task2# : Prediction using Unsupervised ML
#
# Author: Ramesh Kori
#
# ---
#
# Problem statement:
#
# From the given ‘Iris’ dataset, predict the optimum number of clusters and represent it visually.

# %%
# Importing the required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Loading the dataset
data = pd.read_csv("/content/Iris.csv")

# %%
data.head() # The first 5 rows
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# checking for Null values

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# No null values present in dataset

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
pip install sweetviz

# %%
import sweetviz
my_report = sweetviz.analyze([data,'Train'])
my_report.show_html()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
pip install autoviz

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
data = AV.AutoViz('/content/Iris.csv')
# %matplotlib inline
# Out:
# Shape of your Data Set loaded: (150, 6)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
# Data cleaning improvement suggestions. Complete them before proceeding to ML modeling.
# <style type="text/css">
# #T_887ac_row0_col0, #T_887ac_row0_col4, #T_887ac_row5_col5 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_887ac_row0_col1, #T_887ac_row0_col6, #T_887ac_row1_col1, #T_887ac_row1_col6, #T_887ac_row2_col1, #T_887ac_row2_col6, #T_887ac_row3_col1, #T_887ac_row3_col6, #T_887ac_row4_col1, #T_887ac_row4_col6, #T_887ac_row5_col1, #T_887ac_row5_col6 {
#   font-family: Segoe UI;
# }
# #T_887ac_row0_col2, #T_887ac_row0_col3, #T_887ac_row0_col5, #T_887ac_row1_col2, #T_887ac_row1_col3, #T_887ac_row1_col5, #T_887ac_row2_col2, #T_887ac_row2_col3, #T_887ac_row2_col5, #T_887ac_row3_col2, #T_887ac_row3_col3, #T_887ac_row3_col5, #T_887ac_row4_col2, #T_887ac_row4_col3, #T_887ac_row4_col5, #T_887ac_row5_col0, #T_887ac_row5_col2, #T_887ac_row5_col3, #T_887ac_row5_col4 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_887ac_row1_col0, #T_887ac_row1_col4 {
#   background-color: #fcb499;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_887ac_row2_col0, #T_887ac_row2_col4 {
#   background-color: #fdc5ae;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_887ac_row3_col0, #T_887ac_row3_col4 {
#   background-color: #fedecf;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_887ac_row4_col0, #T_887ac_row4_col4 {
#   background-color: #fedfd0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_887ac_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Nuniques</th>
#       <th class="col_heading level0 col1" >dtype</th>
#       <th class="col_heading level0 col2" >Nulls</th>
#       <th class="col_heading level0 col3" >Nullpercent</th>
#       <th class="col_heading level0 col4" >NuniquePercent</th>
#       <th class="col_heading level0 col5" >Value counts Min</th>
#       <th class="col_heading level0 col6" >Data cleaning improvement suggestions</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_887ac_level0_row0" class="row_heading level0 row0" >Id</th>
#       <td id="T_887ac_row0_col0" class="data row0 col0" >150</td>
#       <td id="T_887ac_row0_col1" class="data row0 col1" >int64</td>
#       <td id="T_887ac_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_887ac_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_887ac_row0_col4" class="data row0 col4" >100.000000</td>
#       <td id="T_887ac_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_887ac_row0_col6" class="data row0 col6" >possible ID column: drop</td>
#     </tr>
#     <tr>
#       <th id="T_887ac_level0_row1" class="row_heading level0 row1" >PetalLengthCm</th>
#       <td id="T_887ac_row1_col0" class="data row1 col0" >43</td>
#       <td id="T_887ac_row1_col1" class="data row1 col1" >float64</td>
#       <td id="T_887ac_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_887ac_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_887ac_row1_col4" class="data row1 col4" >28.666667</td>
#       <td id="T_887ac_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_887ac_row1_col6" class="data row1 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_887ac_level0_row2" class="row_heading level0 row2" >SepalLengthCm</th>
#       <td id="T_887ac_row2_col0" class="data row2 col0" >35</td>
#       <td id="T_887ac_row2_col1" class="data row2 col1" >float64</td>
#       <td id="T_887ac_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_887ac_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_887ac_row2_col4" class="data row2 col4" >23.333333</td>
#       <td id="T_887ac_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_887ac_row2_col6" class="data row2 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_887ac_level0_row3" class="row_heading level0 row3" >SepalWidthCm</th>
#       <td id="T_887ac_row3_col0" class="data row3 col0" >23</td>
#       <td id="T_887ac_row3_col1" class="data row3 col1" >float64</td>
#       <td id="T_887ac_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_887ac_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_887ac_row3_col4" class="data row3 col4" >15.333333</td>
#       <td id="T_887ac_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_887ac_row3_col6" class="data row3 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_887ac_level0_row4" class="row_heading level0 row4" >PetalWidthCm</th>
#       <td id="T_887ac_row4_col0" class="data row4 col0" >22</td>
#       <td id="T_887ac_row4_col1" class="data row4 col1" >float64</td>
#       <td id="T_887ac_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_887ac_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_887ac_row4_col4" class="data row4 col4" >14.666667</td>
#       <td id="T_887ac_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_887ac_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_887ac_level0_row5" class="row_heading level0 row5" >Species</th>
#       <td id="T_887ac_row5_col0" class="data row5 col0" >3</td>
#       <td id="T_887ac_row5_col1" class="data row5 col1" >object</td>
#       <td id="T_887ac_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_887ac_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_887ac_row5_col4" class="data row5 col4" >2.000000</td>
#       <td id="T_887ac_row5_col5" class="data row5 col5" >50</td>
#       <td id="T_887ac_row5_col6" class="data row5 col6" ></td>
#     </tr>
#   </tbody>
# </table>
#     6 Predictors classified...
#         1 variables removed since they were ID or low-information variables
#         List of variables removed: ['Id']
# Number of All Scatter Plots = 10
# All Plots done
# Time to run AutoViz = 6 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################

# %% [markdown]
# Correlation between features

# %%
corr = data.corr()
sns.heatmap(data= corr, annot = True)

# %%
tmp = data.drop('Id', axis=1)
sns.pairplot(tmp, hue="Species", diag_kind="hist", size=1.6);

# %%
# Finding the optimum number of clusters for k-means classification
x = data.iloc[:, [0, 1, 2, 3]].values

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)

# %% [markdown]
# Plotting the results onto a line graph to observe 'The elbow'

# %%
plt.plot(range(1, 11), wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') # Within cluster sum of squares
plt.show()

# %% [markdown]
# "The elbow method" got its name from the elbow pattern forming something like above. The optimal clusters are formed where the elbow occurs. This is when the WCSS(Within Cluster Sum of Squares) doesn't decrease with every iteration significantly.
#
# **Here we choose the number of clusters as '3'**

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
y_kmeans = kmeans.fit_predict(x)

# %%
# Visualising the clusters 
# Preferably on the first two columns
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Iris-setosa')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Iris-versicolour')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s = 100, c = 'green', label = 'Iris-virginica')
plt.legend()

# %%
# Plotting the centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], s = 100, c = 'yellow', label = 'Centroids')
plt.legend()

# %%
# Visualising the clusters 
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Iris-setosa')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Iris-versicolour')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s = 100, c = 'black', label = 'Iris-virginica')

# Plotting centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], s = 100, c = 'yellow', label = 'Centroids')
plt.legend()

# %% [markdown]
# ## **THANK YOU**
